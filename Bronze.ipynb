# %%
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("abfs://bronze@storagekevinav.dfs.core.windows.net/sales_view/customer/")
display(df)

# %%
df.repartition(1).write.mode("overwrite").format("csv").option("header","True").save("/Volumes/assignment_adf/adf_layers/bronze")

# %%
spark.read.csv("/Volumes/assignment_adf/adf_layers/bronze",header=True,inferSchema=True).display()
